# %% [markdown]
# <h1>Nu Nu's code</h1>

# %%
import csv
with open(r"C:\Users\JH586JA\OneDrive - EY\Documents\C.csv") as file:
    csvreaderC = csv.reader(file)
    for row in csvreaderC: 
        print(row)

with open(r"C:\Users\JH586JA\OneDrive - EY\Documents\BAC.csv") as file:
    csvreaderBAC = csv.reader(file)
    for row in csvreaderBAC: 
        print(row)

with open(r"C:\Users\JH586JA\OneDrive - EY\Documents\WFC.csv") as file:
    csvreaderWFC = csv.reader(file)
    for row in csvreaderWFC: 
        print(row)

with open(r"C:\Users\JH586JA\OneDrive - EY\Documents\PNC.csv") as file:
    csvreaderPNC = csv.reader(file)
    for row in csvreaderPNC: 
        print(row)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# ['2022-06-06', '51.799999', '52.570000', '51.369999', '51.400002', '50.898106', '18473200']
# ['2022-06-07', '51.029999', '52.230000', '50.830002', '52.099998', '51.591267', '15528800']
# ['2022-06-08', '51.700001', '52.110001', '51.060001', '51.410000', '50.908009', '13207700']
# ['2022-06-09', '51.540001', '51.599998', '49.959999', '49.970001', '49.482071', '14272900']
# ['2022-06-10', '48.720001', '49.150002', '47.369999', '47.709999', '47.244137', '28910800']
# ['2022-06-13', '46.660000', '47.009998', '45.400002', '45.689999', '45.243858', '30308400']
# ['2022-06-14', '46.189999', '46.730000', '45.549999', '45.959999', '45.511223', '25223600']
# ['2022-06-15', '46.470001', '48.180000', '46.450001', '47.580002', '47.115406', '30001500']
# ['2022-06-16', '46.799999', '47.189999', '45.959999', '46.889999', '46.432144', '24744900']
# ...

# %%
import pandas as pd
C = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\C.csv')
C['Date_time'] = df['Date'].astype('datetime64[ns]')
print("\nEarliest date from C dataset:")
print(df.Date_time.max())
print("\nOldest date from C dataset:")
print(df.Date_time.min())

BAC = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\BAC.csv')
BAC['Date_time'] = df['Date'].astype('datetime64[ns]')
print("\nEarliest date from BAC dataset:")
print(df.Date_time.max())
print("\nOldest date from BAC dataset:")
print(df.Date_time.min())

WFC = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\WFC.csv')
WFC['Date_time'] = df['Date'].astype('datetime64[ns]')
print("\nEarliest date from WFC dataset:")
print(df.Date_time.max())
print("\nOldest date from WFC dataset:")
print(df.Date_time.min())

PNC = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\PNC.csv')
PNC['Date_time'] = df['Date'].astype('datetime64[ns]')
print("\nEarliest date from PNC dataset:")
print(df.Date_time.max())
print("\nOldest date from PNC dataset:")
print(df.Date_time.min())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5f269ee044f2> in <module>
#       1 import pandas as pd
#       2 C = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\C.csv')
# ----> 3 C['Date_time'] = df['Date'].astype('datetime64[ns]')
#       4 print("\nEarliest date from C dataset:")
#       5 print(df.Date_time.max())
#
# NameError: name 'df' is not defined

# %%
import csv
import pandas as pd

with open(r'C:\Users\JH586JA\OneDrive - EY\Documents\SPY.csv') as file:
    csvreaderSPY = csv.reader(file)
    for row in csvreaderSPY: 
        print(row)
        
SPY = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\C.csv')
SPY['Date_time'] = df['Date'].astype('datetime64[ns]')
print("\nEarliest date from SPY dataset:")
print(df.Date_time.max())
print("\nOldest date from SPY dataset:")
print(df.Date_time.min())

with open(r'C:\Users\JH586JA\OneDrive - EY\Documents\^TNX.csv') as file:
    csvreaderTNX = csv.reader(file)
    for row in csvreaderTNX: 
        print(row)
        
TNX = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\^TNX.csv')
TNX['Date_time'] = df['Date'].astype('datetime64[ns]')
print("\nEarliest date from TNX dataset:")
print(df.Date_time.max())
print("\nOldest date from TNX dataset:")
print(df.Date_time.min())
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
# ['2021-08-03', '438.440002', '441.279999', '436.100006', '441.149994', '434.965668', '58053900']
# ['2021-08-04', '439.779999', '441.119995', '438.730011', '438.980011', '432.826111', '46732200']
# ['2021-08-05', '440.220001', '441.850006', '439.880005', '441.760010', '435.567139', '38969700']
# ['2021-08-06', '442.100006', '442.940002', '441.799988', '442.489990', '436.286865', '46930000']
# ['2021-08-09', '442.459991', '442.799988', '441.309998', '442.130005', '435.931946', '41222600']
# ['2021-08-10', '442.609985', '443.440002', '441.880005', '442.679993', '436.474243', '43339300']
# ['2021-08-11', '443.820007', '443.880005', '442.619995', '443.779999', '437.558807', '44034300']
# ['2021-08-12', '443.619995', '445.260010', '442.660004', '445.109985', '438.870148', '38909400']
# ['2021-08-13', '445.589996', '445.940002', '445.070007', '445.920013', '439.668823', '39470300']
# ...

# %%
import csv
import pandas as pd

C = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\C.csv')
a = C['Close'].pct_change()
print("C percentage change for close collum\n", a)

BAC = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\BAC.csv')
a = BAC['Close'].pct_change()
print("BAC percentage change for close collum\n", a)

WFC = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\WFC.csv')
a = WFC['Close'].pct_change()
print("WFC percentage change for close collum\n", a)

PNC = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\PNC.csv')
a = PNC['Close'].pct_change()
print("PNC percentage change for close collum\n", a)

SPY = pd.read_csv(r'C:\Users\JH586JA\OneDrive - EY\Documents\SPY.csv')
a = SPY['Close'].pct_change()
print("SPY percentage change for close collum\n", a)
# Out:
# C percentage change for close collum
#  0          NaN
# 1     0.013619
# 2    -0.013244
# 3    -0.028010
# 4    -0.045227
# 5    -0.042339
# 6     0.005909
# 7     0.035248
# 8    -0.014502
# 9    -0.007891
# 10    0.030954
# 11   -0.015846
# 12   -0.018009
# 13    0.032578
# 14   -0.000627
# 15   -0.012963
# 16   -0.002330
# 17   -0.023567
# 18    0.019135
# 19   -0.005547
# 20   -0.009869
# 21    0.016901
# Name: Close, dtype: float64
# BAC percentage change for close collum
#  0          NaN
# 1     0.005532
# 2    -0.012655
# 3    -0.038451
# 4    -0.038829
# 5    -0.034670
# 6    -0.017489
# 7     0.018754
# 8    -0.006240
# 9     0.002198
# 10    0.029135
# 11   -0.007610
# 12   -0.015951
# 13    0.007170
# 14    0.001238
# 15   -0.002782
# 16   -0.012399
# 17   -0.022913
# 18    0.013813
# 19   -0.010139
# 20   -0.008323
# 21    0.028405
# Name: Close, dtype: float64
# WFC percentage change for close collum
#  0          NaN
# 1     0.007757
# 2    -0.018474
# 3    -0.043917
# ...

# %% [markdown]
# <h1>William's code</h1>

# %%
import pandas as pd

C_data = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/C?period1=1654473600&period2=1657238400&interval=1d&events=history&includeAdjustedClose=true')
BAC_data = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/BAC?period1=1654473600&period2=1657238400&interval=1d&events=history&includeAdjustedClose=true')
WFC_data = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/WFC?period1=1654473600&period2=1657238400&interval=1d&events=history&includeAdjustedClose=true')
PNC_data = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/PNC?period1=1654473600&period2=1657238400&interval=1d&events=history&includeAdjustedClose=true')
TNX_data = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/%5ETNX?period1=1654473600&period2=1657238400&interval=1d&events=history&includeAdjustedClose=true')
SPY_data = pd.read_csv('https://query1.finance.yahoo.com/v7/finance/download/SPY?period1=1654473600&period2=1657238400&interval=1d&events=history&includeAdjustedClose=true')

# %%
banks = [C_data, BAC_data, WFC_data, PNC_data, TNX_data, SPY_data]

for bank in banks:
    print(bank['Date'].max())
    print(bank['Date'].min())
# Out:
# 2022-07-07
# 2022-06-06
# 2022-07-07
# 2022-06-06
# 2022-07-07
# 2022-06-06
# 2022-07-07
# 2022-06-06
# 2022-07-07
# 2022-06-06
# 2022-07-07
# 2022-06-06

# %%
percent_changes_list = []

for bank in banks:
    changes_column = []
    for i in range(1, C_data['Close'].size):
        changes_column.append( (C_data['Close'][i] - C_data['Close'][i-1]) / C_data['Close'][i-1] )
    percent_changes_list.append(changes_column)
    
print(percent_changes_list)
# Out:
# [[0.013618598691883295, -0.01324372411684167, -0.028010095312195938, -0.04522717540069691, -0.042339133144815265, 0.00590938949243582, 0.03524810781653839, -0.014501953993192292, -0.007890787116459524, 0.03095440670679278, -0.015846497411311517, -0.018008537754056423, 0.03257827540790827, -0.0006268073416880321, -0.012962637969364855, -0.0023300360586748585, -0.023566795055914917, 0.019134528413371304, -0.0055472158213616144, -0.00986910513046323, 0.016901364381305965], [0.013618598691883295, -0.01324372411684167, -0.028010095312195938, -0.04522717540069691, -0.042339133144815265, 0.00590938949243582, 0.03524810781653839, -0.014501953993192292, -0.007890787116459524, 0.03095440670679278, -0.015846497411311517, -0.018008537754056423, 0.03257827540790827, -0.0006268073416880321, -0.012962637969364855, -0.0023300360586748585, -0.023566795055914917, 0.019134528413371304, -0.0055472158213616144, -0.00986910513046323, 0.016901364381305965], [0.013618598691883295, -0.01324372411684167, -0.0
# ...

# %%
pcl = pd.DataFrame(percent_changes_list).transpose()
print(pcl)
# Out:
#            0         1         2         3         4         5
# 0   0.013619  0.013619  0.013619  0.013619  0.013619  0.013619
# 1  -0.013244 -0.013244 -0.013244 -0.013244 -0.013244 -0.013244
# 2  -0.028010 -0.028010 -0.028010 -0.028010 -0.028010 -0.028010
# 3  -0.045227 -0.045227 -0.045227 -0.045227 -0.045227 -0.045227
# 4  -0.042339 -0.042339 -0.042339 -0.042339 -0.042339 -0.042339
# 5   0.005909  0.005909  0.005909  0.005909  0.005909  0.005909
# 6   0.035248  0.035248  0.035248  0.035248  0.035248  0.035248
# 7  -0.014502 -0.014502 -0.014502 -0.014502 -0.014502 -0.014502
# 8  -0.007891 -0.007891 -0.007891 -0.007891 -0.007891 -0.007891
# 9   0.030954  0.030954  0.030954  0.030954  0.030954  0.030954
# 10 -0.015846 -0.015846 -0.015846 -0.015846 -0.015846 -0.015846
# 11 -0.018009 -0.018009 -0.018009 -0.018009 -0.018009 -0.018009
# 12  0.032578  0.032578  0.032578  0.032578  0.032578  0.032578
# 13 -0.000627 -0.000627 -0.000627 -0.000627 -0.000627 -0.000627
# ...
