# %%
import pandas as pd

cleanedData = pd.read_excel(r'C:\Users\JH586JA\OneDrive - EY\Documents\Dow Data.xlsx', sheet_name='Cleaned Data')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-86faab8b4a03> in <module>
#       1 import pandas as pd
#       2
# ----> 3 cleanedData = pd.read_excel(r'C:\Users\JH586JA\OneDrive - EY\Documents\Dow Data.xlsx', sheet_name='Cleaned Data')
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
deletedData = pd.read_excel(r'C:\Users\JH586JA\OneDrive - EY\Documents\Dow Data.xlsx', sheet_name='Deleted Data')

# %%
crossReferenceData = pd.read_excel(r'C:\Users\JH586JA\Downloads\- 2Q2019-4Q2021_Invoice Spend_PostSpin_EY_VendorDetail(Alex) .xlsx', sheet_name='Lines Removed'
